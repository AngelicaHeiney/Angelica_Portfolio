# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\amrin\OneDrive\Documents\python\supply_chain_data.csv")
data
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 2      haircare   SKU2  11.319683            34                        8
# 3      skincare   SKU3  61.163343            68                       83
# 4      skincare   SKU4   4.805496            26                      871
# 5      haircare   SKU5   1.699976            87                      147
# 6      skincare   SKU6   4.078333            48                       65
# 7     cosmetics   SKU7  42.958384            59                      426
# 8     cosmetics   SKU8  68.717597            78                      150
# 9      skincare   SKU9  64.015733            35                      980
# 10     skincare  SKU10  15.707796            11                      996
# 11     skincare  SKU11  90.635460            95                      960
# ...

# %%
pd.set_option('display.max.column', 30)
pd.set_option('display.max.rows', 150)

# %%
data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  Shipping times Shipping carriers  Shipping costs  \
# ...

# %%
data.drop_duplicates(keep = False, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
import matplotlib.pyplot as plt

# %%
data['Product type'].value_counts().plot(kind='bar')
plt.title('Product Types')
plt.show()

# %%
best_sellers = data.groupby('Product type')['Number of products sold'].sum().sort_values(ascending=False)
best_sellers
# Out:
# Product type
# skincare     20731
# haircare     13611
# cosmetics    11757
# Name: Number of products sold, dtype: int64

# %%
data['Revenue Contribution (%)'] = (data['Revenue generated'] / data['Revenue generated'].sum()) * 100
data['Revenue Contribution (%)']
# Out:
# 0     1.499641
# 1     1.291696
# 2     1.658184
# 3     1.344663
# 4     0.465111
# 5     0.489668
# 6     1.354469
# 7     1.470920
# 8     1.301472
# 9     0.860648
# 10    0.403557
# 11    1.056076
# 12    0.497527
# 13    0.701646
# 14    1.498182
# 15    0.942182
# 16    1.117338
# 17    0.455224
# 18    1.621294
# 19    0.442083
# 20    1.407195
# 21    1.226973
# 22    0.413918
# 23    1.533638
# 24    1.566656
# 25    0.376516
# 26    0.643432
# 27    0.465103
# 28    1.059085
# 29    1.440241
# 30    0.478933
# 31    1.671581
# 32    1.657111
# 33    0.891613
# 34    1.568843
# 35    1.132492
# 36    1.311174
# 37    0.422147
# 38    1.678019
# 39    0.331103
# 40    0.991155
# 41    0.955879
# 42    0.318489
# 43    0.993313
# 44    1.238266
# 45    0.912035
# 46    0.442650
# 47    1.227392
# 48    1.280646
# 49    1.385309
# 50    1.023344
# 51    1.708169
# 52    1.633602
# 53    1.425254
# 54    1.054012
# 55    0.506518
# 56    0.825308
# 57    0.278022
# ...

# %%
plt.figure(figsize=(6, 4))
data.groupby('Product type')['Revenue generated'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title('Revenue by Product Type')
plt.xlabel('Product Type')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_products = data.groupby('Product type')['Revenue generated'].sum().sort_values(ascending=False).head(3)
print("\nTop 3 revenue-generating products:")
print(top_products)
# Out:
# Top 3 revenue-generating products:
# Product type
# skincare     241628.162133
# haircare     174455.390605
# cosmetics    161521.265999
# Name: Revenue generated, dtype: float64

# %%
data.plot.scatter(x='Stock levels', y='Lead times')
# Out:
# <Axes: xlabel='Stock levels', ylabel='Lead times'>

# %%
data[['Lead times', 'Defect rates', 'Stock levels', 'Manufacturing costs']].corr()
# Out:
#                      Lead times  Defect rates  Stock levels  \
# Lead times             1.000000      0.015681      0.072571
# Defect rates           0.015681      1.000000     -0.149478
# Stock levels           0.072571     -0.149478      1.000000
# Manufacturing costs   -0.024441     -0.007819      0.033243
#
#                      Manufacturing costs
# Lead times                     -0.024441
# Defect rates                   -0.007819
# Stock levels                    0.033243
# Manufacturing costs             1.000000

# %%
data.groupby('Location')['Lead times'].mean()
# Out:
# Location
# Bangalore    15.333333
# Chennai      17.150000
# Delhi        17.666667
# Kolkata      15.920000
# Mumbai       14.272727
# Name: Lead times, dtype: float64

# %%
import numpy as np

# %%
#Location by Lead times

# %%
data.groupby('Shipping carriers')[['Shipping times', 'Shipping costs']].mean()
# Out:
#                    Shipping times  Shipping costs
# Shipping carriers
# Carrier A                6.142857        5.554923
# Carrier B                5.302326        5.509247
# Carrier C                6.034483        5.599292

# %%
plt.figure(figsize=(5, 4))
avg_shipping = data.groupby('Shipping carriers')['Shipping times'].mean().sort_values(ascending=False)
avg_shipping.plot(kind='bar')
plt.title('Average Shipping Times by Carrier')
plt.xlabel('Carrier')
plt.ylabel('Average Shipping Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data.groupby('Routes')[['Shipping times', 'Shipping costs']].mean()
# Out:
#          Shipping times  Shipping costs
# Routes
# Route A        6.023256        5.379699
# Route B        5.702703        5.551986
# Route C        5.250000        5.903218

# %%
grouped_data = data.groupby('Routes')[['Shipping times', 'Shipping costs']].mean()

plt.figure(figsize=(6, 3))
plt.plot(grouped_data.index, grouped_data['Shipping times'], marker='o', label='Shipping Times', color='blue')
plt.plot(grouped_data.index, grouped_data['Shipping costs'], marker='o', label='Shipping Costs', color='green')
plt.xlabel('Routes', fontsize=14)
plt.ylabel('Average Values', fontsize=14)
plt.title('Average Shipping Times and Costs by Route', fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
supplier_performance = data.groupby('Supplier name')[['Lead times', 'Defect rates', 'Manufacturing costs']].mean()
supplier_performance
# Out:
#                Lead times  Defect rates  Manufacturing costs
# Supplier name
# Supplier 1      16.777778      1.803630            45.254027
# Supplier 2      16.227273      2.362750            41.622514
# Supplier 3      14.333333      2.465786            43.634121
# Supplier 4      17.000000      2.337397            62.709727
# Supplier 5      14.722222      2.665408            44.768243

# %%
supplier_performance = data.groupby('Supplier name')[['Lead times', 'Defect rates', 'Manufacturing costs']].mean()

# Plotting directly from the DataFrame
supplier_performance.plot(kind='bar', figsize=(6, 3))

# Customizing the plot
plt.title('Supplier Performance Metrics', fontsize=14)
plt.xlabel('Supplier', fontsize=12)
plt.ylabel('Average Values', fontsize=12)
plt.xticks(rotation=25, fontsize=6)
plt.legend(title="Metrics", fontsize=5)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
data.groupby('Product type')['Defect rates'].mean().sort_values(ascending=False)
# Out:
# Product type
# haircare     2.483150
# skincare     2.334681
# cosmetics    1.919287
# Name: Defect rates, dtype: float64

# %%
data.groupby('Transportation modes')[['Shipping times', 'Shipping costs']].mean()
# Out:
#                       Shipping times  Shipping costs
# Transportation modes
# Air                         5.115385        6.017839
# Rail                        6.571429        5.469098
# Road                        4.724138        5.542115
# Sea                         7.117647        4.970294

# %%
transportation_modes = data.groupby('Transportation modes')[['Shipping times', 'Shipping costs']].mean()
plt.figure(figsize=(6, 3))
plt.plot(transportation_modes.index, transportation_modes['Shipping times'], marker='o', label='Shipping Times', color='blue')
plt.plot(transportation_modes.index, transportation_modes['Shipping costs'], marker='o', label='Shipping Costs', color='green')
plt.title('Average Shipping Times and Costs by Transportation Modes', fontsize=13)
plt.xlabel('Transportation Modes', fontsize=11)
plt.ylabel('Average Values', fontsize=11)
# Add legend
plt.legend(fontsize=6)

plt.grid(alpha=0.4)
plt.tight_layout()

plt.show()

# %%
revenue_by_region = data.groupby('Location')['Revenue generated'].sum()
revenue_by_region
# Out:
# Location
# Bangalore    102601.723882
# Chennai      119142.815748
# Delhi         81027.701225
# Kolkata      137077.551005
# Mumbai       137755.026877
# Name: Revenue generated, dtype: float64

# %%
regions = revenue_by_region.index
revenues = revenue_by_region.values

# %%
plt.figure(figsize=(5, 3))
plt.scatter(regions, revenues, color='skyblue', s=200, edgecolors='black')
plt.title('Revenue by Region', fontsize=16)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Revenue Generated', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
correlation_matrix = data[['Lead times', 'Defect rates', 'Stock levels', 'Shipping costs']].corr()
correlation_matrix
# Out:
#                 Lead times  Defect rates  Stock levels  Shipping costs
# Lead times        1.000000      0.015681      0.072571       -0.120746
# Defect rates      0.015681      1.000000     -0.149478        0.083139
# Stock levels      0.072571     -0.149478      1.000000        0.072907
# Shipping costs   -0.120746      0.083139      0.072907        1.000000

# %%
sns.heatmap(correlation_matrix.corr(method='pearson'))
# Out:
# <Axes: >

# %%
correlation = data['Defect rates'].corr(data['Manufacturing costs'])
print(f"\nCorrelation between defect rates and manufacturing costs: {correlation:.2f}")
# Out:
# Correlation between defect rates and manufacturing costs: -0.01

# %% [markdown]
# #Findings:
# Skincare is the product type with more revenue. Haircare is the product with more Defect Rates
#
# Mumbai is the region with shorter lead times and at the same time with the most revenue by region. Delhi has the longer Lead times and smallest renevue. You should pay attention to this region.
#
# There is no a significant difference between carriers according to shipping costs but Carrier B is the fastest carrier with a mean of 5.3
#
# Route C is the best option if speed is the main concern, despite being the most expensive.
# Route A is the best option if cost is the priority, even though it is the slowest.
# Route B provides a balanced option with moderate shipping time and cost.
#
#
# Best Supplier Based on Priorities:
# Balanced option: Supplier 2 or Supplier 3
# Speed priority: Supplier 3.
# Quality priority: Supplier 1.
# Cost priority: Supplier 2.
#
# If you want the best overall balance, choose Supplier 2 (low cost, moderate defect rate, moderate lead time).
# If lead time is the most critical, choose Supplier 3 (fastest delivery).
# If quality is paramount, choose Supplier 1 (lowest defect rate).
#
# Transportation modes:
# Road the fastest but the second most expensive next to Air
# Sea is the slowest but the chepeast.
# Order of efficiency (fast to slow):
# Road > Air > Rail > Sea
#
# For overall balance:
# Fast delivery priority: Use Road (fastest shipping time with moderate cost).
# Low cost priority: Use Sea (cheapest shipping option with the lowest cost per day).
# Balanced option: Use Rail (moderate shipping time and cost).
